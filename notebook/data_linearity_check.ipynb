# %%
import pandas as pd
df = pd.read_csv('../data/stud.csv')

# %%
num_cols = df.select_dtypes(exclude="object").columns
cat_cols = df.select_dtypes(include="object").columns

# %%
cat_cols = cat_cols.union(["math_score"])

# %%
import seaborn as sns

sns.pairplot(df[num_cols], hue="math_score")
# Out:
# c:\Users\fhash\anaconda3\envs\mlgen\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## some linearity here

# %%
sns.stripplot(data=df[cat_cols], x="lunch", y="gender", hue="math_score")
# Out:
# <Axes: xlabel='lunch', ylabel='gender'>

# %%
# no identified pattern here, data spread almost uniformly
