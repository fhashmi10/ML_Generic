# %% [markdown]
# ##### For classification problems

# %%
from collections import Counter
from matplotlib import pyplot
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/xx.csv')

X = df.drop(columns=['target'], axis=1)
y = df['target']

# %%
# summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({'N': 753, 'Y': 247})

# %%
#### There is class imbalance

# %%
# scatter plot of examples by class label
X_arr=np.array(X)
for label, _ in counter.items():
	row_ix = np.where(y == label)[0]
	pyplot.scatter(X_arr[row_ix, 0], X_arr[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %%
# %pip install imbalanced-learn
# Out:
# ...
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl.metadata
#   Using cached imbalanced_learn-0.11.0-py3-none-any.whl.metadata (8.3 kB)
# ...
# Using cached imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#preprocessing needs to be performed first
# from imblearn import over_sampling
# # transform the dataset
# oversample = over_sampling.SMOTE(random_state=0)
# X, y = oversample.fit_resample(X, y)
# # summarize the new class distribution
# counter = Counter(y)
# print(counter)
# # scatter plot of examples by class label
# X_arr=np.array(X)
# for label, _ in counter.items():
#  row_ix = np.where(y == label)[0]
#  pyplot.scatter(X_arr[row_ix, 0], X_arr[row_ix, 1], label=str(label))
# pyplot.legend()
# pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20336\2250635712.py in ?()
#       1 from imblearn import over_sampling
#       2 # transform the dataset
#       3 oversample = over_sampling.SMOTE(random_state=0)
# ----> 4 X, y = oversample.fit_resample(X, y)
#       5 # summarize the new class distribution
#       6 counter = Counter(y)
#       7 print(counter)
#
# c:\Users\fhash\anaconda3\envs\autoclaimfrd\lib\site-packages\imblearn\base.py in ?(self, X, y)
#     204         y_resampled : array-like of shape (n_samples_new,)
#     205             The corresponding label of `X_resampled`.
#     206         """
#     207         self._validate_params()
# --> 208         return super().fit_resample(X, y)
#
# c:\Users\fhash\anaconda3\envs\autoclaimfrd\lib\site-packages\imblearn\base.py in ?(self, X, y)
# ...
