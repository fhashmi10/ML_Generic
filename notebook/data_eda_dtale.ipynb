# %%
# !pip install dtale
# Out:
# ...
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/60/20/59a88f23ed06929d6ba5caee48e572a80d46ee3b2cfabe72f1782ceba34f/dtale-3.3.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/62.3 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.3 kB ? eta -:--:--
#      -------------------------------------- 62.3/62.3 kB 827.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ----------- -------------------------- 194.6/642.7 kB 3.9 MB/s eta 0:00:01
#      ------------------ ------------------- 307.2/642.7 kB 3.8 MB/s eta 0:00:01
#      ------------------------------ ------- 522.2/642.7 kB 4.1 MB/s eta 0:00:01
#      -------------------------------------- 642.7/642.7 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
# ...

# %%
import pandas as pd
df = pd.read_csv('../data/stud.csv')

# %%
import dtale
dt = dtale.show(df, notebook=True)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://FarazPC:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
